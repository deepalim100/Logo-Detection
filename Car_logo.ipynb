# %%
# Importing the modules for collecting and building the dataset
import time
import os
import re
# Web-scraping...
from urllib.request import Request, urlopen
from urllib.request import URLError, HTTPError
import pil
# Image processing...
from pil import Image

# %%
cars = [ 'Audi', 'BMW', 'Chevrolet', 'Citroen', 'Volvo']

kwrds = ['logo', 'logotype', 'logo png', 'logo gif', 'logo jpg', 'logo front',
         'logo rear', 'badge', 'logo white', 'logo black', 'logo transparent']

# Importing standard ML set - numpy, pandas, matplotlib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import gridspec

# Importing keras and its deep learning tools - neural network model, layers, contraints, optimizers, callbacks and utilities
from keras.models import Sequential
from keras.layers import Activation, Dense, Dropout, Flatten
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.constraints import maxnorm
from keras.optimizers import adam, RMSprop, SGD
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.utils import np_utils
from keras.regularizers import l2
from keras.initializers import RandomNormal, VarianceScaling

# Importing scikit-learn tools
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

# %%
# Loading the image file
image_path = 'nimg/'
imgs = os.listdir(image_path)
img_x = img_y = 50 # image size is constant
n_samples = np.size(imgs)
n_samples
# Out:
# 105

# %%
# Loading all images...
images = np.array([np.array(Image.open(image_path + img).convert("RGB")).flatten() for img in os.listdir(image_path)], order='F', dtype='uint8')
np.shape(images)
# Out:
# (105, 7500)

# %%
# an example image
images[1][1:]
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=uint8)

# %%
# Producing labels and assigning them accordingly
labels = np.array([cars.index(re.match(r"(^\D+)", imgs[i])[0]) for i in range(n_samples)])
labels.shape
# Out:
# (105,)

# %%
# Some additional data preparation needs to be done before blasting the images into the neural net
dataset, labelset = shuffle(images, labels, random_state=42) # 42, what else? ;)
train_data = [dataset, labelset]

# %%
# Testing 
r = 100
print(train_data[0].shape, train_data[1].shape)
plt.imshow(images[r].reshape(img_x, img_y, 3))
plt.title(cars[labels[r]])
plt.show()
# Out:
# (105, 7500) (105,)

# %% [markdown]
# # Training the dataset

# %%
# We have to prepare the dataset to fit into the CNN
X_train, X_test, y_train, y_test = train_test_split(train_data[0], train_data[1], test_size=0.2)

# we will maintain a copy of the test set
X_test_img = X_test.copy()

X_train = X_train.reshape(X_train.shape[0], img_x, img_y, 3)
X_test = X_test.reshape(X_test.shape[0], img_x, img_y, 3)

X_train = X_train.astype('float32') / 255
X_test = X_test.astype('float32') / 255

#some additional pre-processing.
X_train = np.subtract(X_train, 0.5)
X_test = np.subtract(X_test, 0.5)

#scale it to (-1, 1)
X_train = np.multiply(X_train, 2.0)
X_test = np.multiply(X_test, 2.0)

# Labels have to be transformed to categorical
Y_train = np_utils.to_categorical(y_train, num_classes=len(cars))
Y_test = np_utils.to_categorical(y_test, num_classes=len(cars))

# %%
#Shape of data
X_train.shape, X_test.shape
# Out:
# ((84, 50, 50, 3), (21, 50, 50, 3))

# %% [markdown]
# # Data Agumentation

# %%
# In order to process data augmentation, keras' ImageDataGenerator can apply some transformations to images on random
from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    rotation_range=45,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    vertical_flip=True)

# %%
# It has to be 'fit' into the training set
datagen.fit(X_train)

# %% [markdown]
# # Buliding the CNN model

# %%
# some CNN construction!

# setting up batch size 
batch = 64

# there are 5 brands altogether
n_classes = len(cars)

# setting up the number of epochs to be trained
n_epochs = 1500

# images are RGB, so they use up 3 channels for Red, Green and Blue, respectively
n_channels = 3

# %%
# Convolutional Neural Network will be composed of four Conv/MaxPool blocks, a flattening layer and two dense layers at the end
# (before the final classification layer, that is)

model = Sequential()
model.add(Conv2D(32, (3,3),
                 input_shape=(img_x,img_y,n_channels),
                 padding='valid',
                 bias_initializer='glorot_uniform',
                 kernel_regularizer=l2(0.00004),
                 kernel_initializer=VarianceScaling(scale=2.0, mode='fan_in', distribution='normal', seed=None),
                 activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(64, (3,3),
                 padding='valid',
                 bias_initializer='glorot_uniform',
                 kernel_regularizer=l2(0.00004),
                 kernel_initializer=VarianceScaling(scale=2.0, mode='fan_in', distribution='normal', seed=None),
                 activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(128, (3,3),
                 padding='valid',
                 bias_initializer='glorot_uniform',
                 kernel_regularizer=l2(0.00004),
                 kernel_initializer=VarianceScaling(scale=2.0, mode='fan_in', distribution='normal', seed=None),
                 activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(256, (3,3),
                 padding='valid',
                 bias_initializer='glorot_uniform',
                 kernel_regularizer=l2(0.00004),
                 kernel_initializer=VarianceScaling(scale=2.0, mode='fan_in', distribution='normal', seed=None),
                 activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())

model.add(Dense(4096, activation='relu', bias_initializer='glorot_uniform'))
model.add(Dropout(0.5))


model.add(Dense(4096, activation='relu', bias_initializer='glorot_uniform'))
model.add(Dropout(0.5))

# final activation is softmax, tuned to the number of classes/labels possible
model.add(Dense(len(cars), activation='softmax'))

# Some callbacks have to be provided to choose the best trained model

early_stopping = EarlyStopping(patience=4, monitor='val_loss')
CNN_file = 'car_CNN_13AUGM_CMCMCMCMF.h5py' 
take_best_model = ModelCheckpoint(CNN_file, save_best_only=True)

# optimizer will be a stochastic gradient descent, learning rate set at 0.005
sgd = SGD(lr=0.005, decay=1e-6, momentum=0.95, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['categorical_accuracy'])

# Let's look at the summary
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_9 (Conv2D)            (None, 48, 48, 32)        896
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 24, 24, 32)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 22, 22, 64)        18496
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 11, 11, 64)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 9, 9, 128)         73856
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 4, 4, 128)         0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 2, 2, 256)         295168
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 1, 1, 256)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 4096)              1052672
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 5)                 20485
# =================================================================
# Total params: 18,242,885
# Trainable params: 18,242,885
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Image data generator

# %% [markdown]
# First I used batch=32 and epoch=500 then I got 66.67% accuracy.
# I have updated my batch_size to 64 and epoch size 800 then I got 71.23% Accuracy.
# now I have updated my epoch to 1200 I got 76.19% accuracy. I have updated epoch to 1500 and I got success rate of 94%.

# %%
#Training
model.fit_generator(datagen.flow(X_train, Y_train, batch_size=batch, shuffle=True, seed=42),\
                    steps_per_epoch=X_train.shape[0]//batch, epochs=n_epochs,\
                    validation_data=(X_test, Y_test), workers=4)
# Out:
# Epoch 1/1500
# 1/1 [==============================] - 4s 4s/step - loss: 1.7134 - categorical_accuracy: 0.2500 - val_loss: 1.6112 - val_categorical_accuracy: 0.2857
# Epoch 2/1500
# 1/1 [==============================] - 0s 420ms/step - loss: 1.8712 - categorical_accuracy: 0.1500 - val_loss: 2.3890 - val_categorical_accuracy: 0.0952
# Epoch 3/1500
# 1/1 [==============================] - 1s 650ms/step - loss: 2.1742 - categorical_accuracy: 0.2031 - val_loss: 1.5616 - val_categorical_accuracy: 0.3333
# Epoch 4/1500
# 1/1 [==============================] - 0s 406ms/step - loss: 1.7711 - categorical_accuracy: 0.2000 - val_loss: 1.8387 - val_categorical_accuracy: 0.2381
# Epoch 5/1500
# 1/1 [==============================] - 1s 665ms/step - loss: 1.6838 - categorical_accuracy: 0.2656 - val_loss: 1.7311 - val_categorical_accuracy: 0.1905
# Epoch 6/1500
# 1/1 [==============================] - 0s 487ms/step - loss: 1.7394 - categorical_accuracy: 0.2000 - val_loss: 1.5420 - val_categorical_accuracy: 0.2381
# Epoch 7/1500
# 1/1 [==============================] - 1s 591ms/step - loss: 1.6392 - categorical_accuracy: 0.2500 - val_loss: 1.4881 - val_categorical_accuracy: 0.5238
# Epoch 8/1500
# 1/1 [==============================] - 0s 361ms/step - loss: 1.8634 - categorical_accuracy: 0.3000 - val_loss: 1.9109 - val_categorical_accuracy: 0.0952
# Epoch 9/1500
# 1/1 [==============================] - 1s 654ms/step - loss: 1.7133 - categorical_accuracy: 0.2188 - val_loss: 1.6371 - val_categorical_accuracy: 0.2857
# Epoch 10/1500
# 1/1 [==============================] - 0s 361ms/step - loss: 1.5099 - categorical_accuracy: 0.2000 - val_loss: 1.7658 - val_categorical_accuracy: 0.1429
# Epoch 11/1500
# 1/1 [==============================] - 1s 683ms/step - loss: 1.6848 - categorical_accuracy: 0.2031 - val_loss: 1.6642 - val_categorical_accuracy: 0.1429
# Epoch 12/1500
# 1/1 [==============================] - 0s 368ms/step - loss: 1.5691 - categorical_accuracy: 0.2500 - val_loss: 1.7407 - val_categorical_accuracy: 0.2381
# Epoch 13/1500
# 1/1 [==============================] - 1s 637ms/step - loss: 1.6677 - categorical_accuracy: 0.2812 - val_loss: 1.6483 - val_categorical_accuracy: 0.2381
# Epoch 14/1500
# 1/1 [==============================] - 0s 489ms/step - loss: 1.5762 - categorical_accuracy: 0.3500 - val_loss: 1.5698 - val_categorical_accuracy: 0.2857
# Epoch 15/1500
# 1/1 [==============================] - 1s 615ms/step - loss: 1.6250 - categorical_accuracy: 0.3750 - val_loss: 1.4718 - val_categorical_accuracy: 0.3810
# Epoch 16/1500
# 1/1 [==============================] - 0s 432ms/step - loss: 1.4143 - categorical_accuracy: 0.5000 - val_loss: 1.6389 - val_categorical_accuracy: 0.4762
# Epoch 17/1500
# 1/1 [==============================] - 1s 688ms/step - loss: 1.6153 - categorical_accuracy: 0.3438 - val_loss: 1.5636 - val_categorical_accuracy: 0.2857
# Epoch 18/1500
# 1/1 [==============================] - 0s 474ms/step - loss: 1.6046 - categorical_accuracy: 0.3500 - val_loss: 1.6586 - val_categorical_accuracy: 0.3810
# Epoch 19/1500
# 1/1 [==============================] - 1s 824ms/step - loss: 1.5808 - categorical_accuracy: 0.3125 - val_loss: 1.5385 - val_categorical_accuracy: 0.3333
# Epoch 20/1500
# 1/1 [==============================] - 0s 460ms/step - loss: 1.5107 - categorical_accuracy: 0.3000 - val_loss: 1.5692 - val_categorical_accuracy: 0.2857
# Epoch 21/1500
# 1/1 [==============================] - 1s 605ms/step - loss: 1.5118 - categorical_accuracy: 0.3750 - val_loss: 1.5057 - val_categorical_accuracy: 0.4286
# Epoch 22/1500
# 1/1 [==============================] - 0s 381ms/step - loss: 1.6949 - categorical_accuracy: 0.2500 - val_loss: 1.4396 - val_categorical_accuracy: 0.4286
# Epoch 23/1500
# 1/1 [==============================] - 1s 608ms/step - loss: 1.3652 - categorical_accuracy: 0.4219 - val_loss: 1.4327 - val_categorical_accuracy: 0.2857
# Epoch 24/1500
# 1/1 [==============================] - 0s 371ms/step - loss: 1.6335 - categorical_accuracy: 0.3500 - val_loss: 1.4380 - val_categorical_accuracy: 0.4286
# Epoch 25/1500
# 1/1 [==============================] - 1s 597ms/step - loss: 1.3861 - categorical_accuracy: 0.3750 - val_loss: 1.4415 - val_categorical_accuracy: 0.4286
# Epoch 26/1500
# 1/1 [==============================] - 0s 431ms/step - loss: 1.4626 - categorical_accuracy: 0.5000 - val_loss: 1.4363 - val_categorical_accuracy: 0.4286
# Epoch 27/1500
# 1/1 [==============================] - 1s 571ms/step - loss: 1.2985 - categorical_accuracy: 0.5156 - val_loss: 1.4700 - val_categorical_accuracy: 0.3810
# Epoch 28/1500
# 1/1 [==============================] - 0s 365ms/step - loss: 1.4863 - categorical_accuracy: 0.3000 - val_loss: 1.3733 - val_categorical_accuracy: 0.2381
# Epoch 29/1500
# 1/1 [==============================] - 1s 589ms/step - loss: 1.2714 - categorical_accuracy: 0.5000 - val_loss: 1.3107 - val_categorical_accuracy: 0.3810
# Epoch 30/1500
# 1/1 [==============================] - 0s 338ms/step - loss: 1.4910 - categorical_accuracy: 0.4000 - val_loss: 1.3880 - val_categorical_accuracy: 0.2857
# Epoch 31/1500
# 1/1 [==============================] - 1s 559ms/step - loss: 1.3390 - categorical_accuracy: 0.4688 - val_loss: 1.3190 - val_categorical_accuracy: 0.4286
# Epoch 32/1500
# 1/1 [==============================] - 0s 367ms/step - loss: 1.2148 - categorical_accuracy: 0.5500 - val_loss: 1.3716 - val_categorical_accuracy: 0.3333
# Epoch 33/1500
# 1/1 [==============================] - 1s 569ms/step - loss: 1.3565 - categorical_accuracy: 0.3906 - val_loss: 1.3119 - val_categorical_accuracy: 0.5238
# Epoch 34/1500
# 1/1 [==============================] - 0s 380ms/step - loss: 1.1947 - categorical_accuracy: 0.6000 - val_loss: 1.4965 - val_categorical_accuracy: 0.2857
# Epoch 35/1500
# 1/1 [==============================] - 1s 565ms/step - loss: 1.1913 - categorical_accuracy: 0.5312 - val_loss: 1.3788 - val_categorical_accuracy: 0.4286
# Epoch 36/1500
# 1/1 [==============================] - 0s 367ms/step - loss: 1.2545 - categorical_accuracy: 0.6500 - val_loss: 1.3809 - val_categorical_accuracy: 0.4762
# Epoch 37/1500
# 1/1 [==============================] - 1s 582ms/step - loss: 1.1131 - categorical_accuracy: 0.6250 - val_loss: 1.3253 - val_categorical_accuracy: 0.4762
# Epoch 38/1500
# 1/1 [==============================] - 0s 365ms/step - loss: 1.1925 - categorical_accuracy: 0.5500 - val_loss: 1.2876 - val_categorical_accuracy: 0.6190
# Epoch 39/1500
# 1/1 [==============================] - 1s 582ms/step - loss: 1.1680 - categorical_accuracy: 0.5625 - val_loss: 1.2667 - val_categorical_accuracy: 0.5714
# Epoch 40/1500
# 1/1 [==============================] - 0s 368ms/step - loss: 1.3304 - categorical_accuracy: 0.4500 - val_loss: 1.3768 - val_categorical_accuracy: 0.4286
# Epoch 41/1500
# 1/1 [==============================] - 1s 559ms/step - loss: 1.1347 - categorical_accuracy: 0.5938 - val_loss: 1.2763 - val_categorical_accuracy: 0.5238
# Epoch 42/1500
# 1/1 [==============================] - 0s 340ms/step - loss: 0.9329 - categorical_accuracy: 0.6500 - val_loss: 1.5206 - val_categorical_accuracy: 0.4286
# Epoch 43/1500
# 1/1 [==============================] - 1s 570ms/step - loss: 1.0487 - categorical_accuracy: 0.5625 - val_loss: 1.3245 - val_categorical_accuracy: 0.5238
# Epoch 44/1500
# 1/1 [==============================] - 0s 383ms/step - loss: 1.1648 - categorical_accuracy: 0.5000 - val_loss: 1.3010 - val_categorical_accuracy: 0.4286
# Epoch 45/1500
# 1/1 [==============================] - 1s 598ms/step - loss: 1.5382 - categorical_accuracy: 0.4062 - val_loss: 1.2163 - val_categorical_accuracy: 0.5238
# Epoch 46/1500
# 1/1 [==============================] - 0s 366ms/step - loss: 0.8208 - categorical_accuracy: 0.7000 - val_loss: 1.2456 - val_categorical_accuracy: 0.5238
# Epoch 47/1500
# 1/1 [==============================] - 1s 599ms/step - loss: 1.1834 - categorical_accuracy: 0.5156 - val_loss: 1.2118 - val_categorical_accuracy: 0.5238
# Epoch 48/1500
# 1/1 [==============================] - 0s 365ms/step - loss: 0.9983 - categorical_accuracy: 0.5000 - val_loss: 1.4348 - val_categorical_accuracy: 0.5238
# Epoch 49/1500
# 1/1 [==============================] - 1s 584ms/step - loss: 0.9215 - categorical_accuracy: 0.6562 - val_loss: 1.3061 - val_categorical_accuracy: 0.5238
# Epoch 50/1500
# 1/1 [==============================] - 0s 356ms/step - loss: 0.9479 - categorical_accuracy: 0.7000 - val_loss: 1.1873 - val_categorical_accuracy: 0.5238
# Epoch 51/1500
# 1/1 [==============================] - 1s 574ms/step - loss: 1.2342 - categorical_accuracy: 0.5469 - val_loss: 1.1996 - val_categorical_accuracy: 0.5238
# Epoch 52/1500
# 1/1 [==============================] - 0s 375ms/step - loss: 0.9993 - categorical_accuracy: 0.5500 - val_loss: 1.2290 - val_categorical_accuracy: 0.5238
# Epoch 53/1500
# 1/1 [==============================] - 1s 598ms/step - loss: 0.9417 - categorical_accuracy: 0.6406 - val_loss: 1.1927 - val_categorical_accuracy: 0.5714
# Epoch 54/1500
# 1/1 [==============================] - 0s 367ms/step - loss: 1.0175 - categorical_accuracy: 0.5000 - val_loss: 1.1789 - val_categorical_accuracy: 0.5714
# Epoch 55/1500
# 1/1 [==============================] - 1s 582ms/step - loss: 0.9176 - categorical_accuracy: 0.6406 - val_loss: 1.1867 - val_categorical_accuracy: 0.5714
# Epoch 56/1500
# 1/1 [==============================] - 0s 385ms/step - loss: 1.1549 - categorical_accuracy: 0.5500 - val_loss: 1.3842 - val_categorical_accuracy: 0.4286
# Epoch 57/1500
# 1/1 [==============================] - 1s 584ms/step - loss: 0.8096 - categorical_accuracy: 0.6719 - val_loss: 1.3682 - val_categorical_accuracy: 0.4762
# Epoch 58/1500
# 1/1 [==============================] - 0s 380ms/step - loss: 1.3060 - categorical_accuracy: 0.6000 - val_loss: 1.1296 - val_categorical_accuracy: 0.4286
# Epoch 59/1500
# 1/1 [==============================] - 1s 584ms/step - loss: 0.9971 - categorical_accuracy: 0.6250 - val_loss: 1.1574 - val_categorical_accuracy: 0.6190
# Epoch 60/1500
# 1/1 [==============================] - 0s 390ms/step - loss: 1.0413 - categorical_accuracy: 0.6000 - val_loss: 1.3705 - val_categorical_accuracy: 0.5238
# Epoch 61/1500
# 1/1 [==============================] - 1s 656ms/step - loss: 0.8965 - categorical_accuracy: 0.6875 - val_loss: 1.4408 - val_categorical_accuracy: 0.5238
# Epoch 62/1500
# 1/1 [==============================] - 0s 377ms/step - loss: 1.0018 - categorical_accuracy: 0.6000 - val_loss: 1.2397 - val_categorical_accuracy: 0.5238
# Epoch 63/1500
# 1/1 [==============================] - 1s 699ms/step - loss: 1.0290 - categorical_accuracy: 0.5938 - val_loss: 1.2382 - val_categorical_accuracy: 0.5714
# Epoch 64/1500
# 1/1 [==============================] - 0s 404ms/step - loss: 0.8978 - categorical_accuracy: 0.6000 - val_loss: 1.4574 - val_categorical_accuracy: 0.5714
# Epoch 65/1500
# 1/1 [==============================] - 1s 642ms/step - loss: 0.9884 - categorical_accuracy: 0.5781 - val_loss: 1.2896 - val_categorical_accuracy: 0.5714
# Epoch 66/1500
# 1/1 [==============================] - 0s 367ms/step - loss: 1.0006 - categorical_accuracy: 0.5500 - val_loss: 1.2318 - val_categorical_accuracy: 0.5238
# Epoch 67/1500
# 1/1 [==============================] - 1s 605ms/step - loss: 0.9386 - categorical_accuracy: 0.6094 - val_loss: 1.1574 - val_categorical_accuracy: 0.6190
# Epoch 68/1500
# 1/1 [==============================] - 0s 408ms/step - loss: 1.0594 - categorical_accuracy: 0.5500 - val_loss: 1.2818 - val_categorical_accuracy: 0.4762
# Epoch 69/1500
# 1/1 [==============================] - 1s 704ms/step - loss: 0.9040 - categorical_accuracy: 0.6562 - val_loss: 1.2971 - val_categorical_accuracy: 0.5238
# Epoch 70/1500
# 1/1 [==============================] - 0s 422ms/step - loss: 1.1924 - categorical_accuracy: 0.4500 - val_loss: 1.1836 - val_categorical_accuracy: 0.5714
# Epoch 71/1500
# 1/1 [==============================] - 1s 724ms/step - loss: 0.7242 - categorical_accuracy: 0.7656 - val_loss: 1.0989 - val_categorical_accuracy: 0.6190
# Epoch 72/1500
# 1/1 [==============================] - 0s 412ms/step - loss: 0.7840 - categorical_accuracy: 0.7000 - val_loss: 1.1140 - val_categorical_accuracy: 0.5238
# Epoch 73/1500
# 1/1 [==============================] - 1s 670ms/step - loss: 0.7472 - categorical_accuracy: 0.7344 - val_loss: 1.1368 - val_categorical_accuracy: 0.6190
# Epoch 74/1500
# 1/1 [==============================] - 0s 422ms/step - loss: 0.9828 - categorical_accuracy: 0.6000 - val_loss: 1.0356 - val_categorical_accuracy: 0.5714
# Epoch 75/1500
# 1/1 [==============================] - 1s 679ms/step - loss: 0.7151 - categorical_accuracy: 0.7500 - val_loss: 1.0519 - val_categorical_accuracy: 0.6190
# Epoch 76/1500
# 1/1 [==============================] - 0s 420ms/step - loss: 0.7520 - categorical_accuracy: 0.7500 - val_loss: 0.9052 - val_categorical_accuracy: 0.7143
# Epoch 77/1500
# 1/1 [==============================] - 1s 610ms/step - loss: 0.7815 - categorical_accuracy: 0.7344 - val_loss: 0.9720 - val_categorical_accuracy: 0.6190
# Epoch 78/1500
# 1/1 [==============================] - 0s 399ms/step - loss: 0.4996 - categorical_accuracy: 0.9000 - val_loss: 0.9925 - val_categorical_accuracy: 0.6190
# Epoch 79/1500
# 1/1 [==============================] - 1s 639ms/step - loss: 0.7868 - categorical_accuracy: 0.7031 - val_loss: 0.9675 - val_categorical_accuracy: 0.6190
# Epoch 80/1500
# 1/1 [==============================] - 0s 413ms/step - loss: 0.8645 - categorical_accuracy: 0.5500 - val_loss: 0.9471 - val_categorical_accuracy: 0.6190
# Epoch 81/1500
# 1/1 [==============================] - 1s 652ms/step - loss: 0.8513 - categorical_accuracy: 0.7031 - val_loss: 1.0101 - val_categorical_accuracy: 0.6667
# Epoch 82/1500
# 1/1 [==============================] - 0s 434ms/step - loss: 0.7609 - categorical_accuracy: 0.6500 - val_loss: 0.9961 - val_categorical_accuracy: 0.6667
# Epoch 83/1500
# 1/1 [==============================] - 1s 681ms/step - loss: 0.7592 - categorical_accuracy: 0.7188 - val_loss: 1.0489 - val_categorical_accuracy: 0.6667
# Epoch 84/1500
# 1/1 [==============================] - 0s 430ms/step - loss: 0.6071 - categorical_accuracy: 0.7000 - val_loss: 1.0399 - val_categorical_accuracy: 0.5714
# Epoch 85/1500
# 1/1 [==============================] - 1s 665ms/step - loss: 0.6853 - categorical_accuracy: 0.7500 - val_loss: 1.0912 - val_categorical_accuracy: 0.6667
# Epoch 86/1500
# 1/1 [==============================] - 0s 450ms/step - loss: 0.8215 - categorical_accuracy: 0.5500 - val_loss: 1.0423 - val_categorical_accuracy: 0.6667
# Epoch 87/1500
# 1/1 [==============================] - 1s 706ms/step - loss: 0.6944 - categorical_accuracy: 0.8125 - val_loss: 1.0011 - val_categorical_accuracy: 0.6667
# Epoch 88/1500
# 1/1 [==============================] - 0s 441ms/step - loss: 0.4829 - categorical_accuracy: 0.8000 - val_loss: 1.0375 - val_categorical_accuracy: 0.6190
# Epoch 89/1500
# 1/1 [==============================] - 1s 627ms/step - loss: 0.6564 - categorical_accuracy: 0.7500 - val_loss: 0.9983 - val_categorical_accuracy: 0.6667
# Epoch 90/1500
# 1/1 [==============================] - 0s 382ms/step - loss: 0.7367 - categorical_accuracy: 0.7500 - val_loss: 0.9967 - val_categorical_accuracy: 0.6667
# Epoch 91/1500
# 1/1 [==============================] - 1s 634ms/step - loss: 0.6940 - categorical_accuracy: 0.7500 - val_loss: 1.0422 - val_categorical_accuracy: 0.6190
# Epoch 92/1500
# 1/1 [==============================] - 0s 384ms/step - loss: 0.5257 - categorical_accuracy: 0.8000 - val_loss: 1.0524 - val_categorical_accuracy: 0.7619
# Epoch 93/1500
# 1/1 [==============================] - 1s 601ms/step - loss: 0.6886 - categorical_accuracy: 0.7656 - val_loss: 1.3035 - val_categorical_accuracy: 0.5714
# Epoch 94/1500
# 1/1 [==============================] - 0s 375ms/step - loss: 0.5593 - categorical_accuracy: 0.8000 - val_loss: 1.2604 - val_categorical_accuracy: 0.5714
# Epoch 95/1500
# 1/1 [==============================] - 1s 588ms/step - loss: 0.7165 - categorical_accuracy: 0.7500 - val_loss: 1.1491 - val_categorical_accuracy: 0.7143
# Epoch 96/1500
# 1/1 [==============================] - 0s 386ms/step - loss: 0.5630 - categorical_accuracy: 0.8500 - val_loss: 1.7839 - val_categorical_accuracy: 0.5238
# Epoch 97/1500
# 1/1 [==============================] - 1s 597ms/step - loss: 0.8127 - categorical_accuracy: 0.7344 - val_loss: 1.3580 - val_categorical_accuracy: 0.6190
# Epoch 98/1500
# 1/1 [==============================] - 0s 370ms/step - loss: 0.7600 - categorical_accuracy: 0.7000 - val_loss: 1.4133 - val_categorical_accuracy: 0.6667
# Epoch 99/1500
# 1/1 [==============================] - 1s 595ms/step - loss: 0.8420 - categorical_accuracy: 0.7344 - val_loss: 1.4008 - val_categorical_accuracy: 0.6190
# Epoch 100/1500
# 1/1 [==============================] - 0s 367ms/step - loss: 0.4810 - categorical_accuracy: 0.9000 - val_loss: 1.4308 - val_categorical_accuracy: 0.6190
# Epoch 101/1500
# 1/1 [==============================] - 1s 600ms/step - loss: 0.7038 - categorical_accuracy: 0.7656 - val_loss: 1.3575 - val_categorical_accuracy: 0.6667
# Epoch 102/1500
# 1/1 [==============================] - 0s 365ms/step - loss: 0.5301 - categorical_accuracy: 0.8000 - val_loss: 1.3307 - val_categorical_accuracy: 0.6667
# Epoch 103/1500
# 1/1 [==============================] - 1s 598ms/step - loss: 0.3883 - categorical_accuracy: 0.8750 - val_loss: 1.3567 - val_categorical_accuracy: 0.6190
# Epoch 104/1500
# 1/1 [==============================] - 0s 367ms/step - loss: 0.8522 - categorical_accuracy: 0.7000 - val_loss: 1.3515 - val_categorical_accuracy: 0.6190
# Epoch 105/1500
# 1/1 [==============================] - 1s 582ms/step - loss: 0.7621 - categorical_accuracy: 0.7812 - val_loss: 1.3272 - val_categorical_accuracy: 0.6190
# Epoch 106/1500
# 1/1 [==============================] - 0s 383ms/step - loss: 0.7729 - categorical_accuracy: 0.7000 - val_loss: 1.3223 - val_categorical_accuracy: 0.6190
# Epoch 107/1500
# 1/1 [==============================] - 1s 584ms/step - loss: 0.6828 - categorical_accuracy: 0.7656 - val_loss: 1.3290 - val_categorical_accuracy: 0.6190
# Epoch 108/1500
# 1/1 [==============================] - 0s 365ms/step - loss: 0.7832 - categorical_accuracy: 0.6000 - val_loss: 1.6134 - val_categorical_accuracy: 0.6190
# Epoch 109/1500
# 1/1 [==============================] - 1s 568ms/step - loss: 1.1266 - categorical_accuracy: 0.6094 - val_loss: 1.2939 - val_categorical_accuracy: 0.6667
# Epoch 110/1500
# 1/1 [==============================] - 0s 366ms/step - loss: 0.3749 - categorical_accuracy: 0.9000 - val_loss: 1.3180 - val_categorical_accuracy: 0.6190
# Epoch 111/1500
# 1/1 [==============================] - 1s 642ms/step - loss: 0.4516 - categorical_accuracy: 0.8594 - val_loss: 1.3199 - val_categorical_accuracy: 0.6667
# Epoch 112/1500
# 1/1 [==============================] - 0s 388ms/step - loss: 0.6978 - categorical_accuracy: 0.8000 - val_loss: 1.3184 - val_categorical_accuracy: 0.6667
# Epoch 113/1500
# 1/1 [==============================] - 1s 685ms/step - loss: 0.5192 - categorical_accuracy: 0.7344 - val_loss: 1.3177 - val_categorical_accuracy: 0.6190
# Epoch 114/1500
# 1/1 [==============================] - 1s 532ms/step - loss: 0.5899 - categorical_accuracy: 0.8000 - val_loss: 1.3063 - val_categorical_accuracy: 0.6190
# Epoch 115/1500
# 1/1 [==============================] - 1s 633ms/step - loss: 0.5281 - categorical_accuracy: 0.8125 - val_loss: 1.2750 - val_categorical_accuracy: 0.6667
# Epoch 116/1500
# 1/1 [==============================] - 0s 368ms/step - loss: 0.4949 - categorical_accuracy: 0.8000 - val_loss: 1.4108 - val_categorical_accuracy: 0.5714
# Epoch 117/1500
# 1/1 [==============================] - 1s 669ms/step - loss: 0.6270 - categorical_accuracy: 0.7969 - val_loss: 1.0832 - val_categorical_accuracy: 0.6667
# Epoch 118/1500
# 1/1 [==============================] - 0s 416ms/step - loss: 0.7161 - categorical_accuracy: 0.6000 - val_loss: 1.3065 - val_categorical_accuracy: 0.6190
# Epoch 119/1500
# 1/1 [==============================] - 1s 667ms/step - loss: 0.7814 - categorical_accuracy: 0.7656 - val_loss: 1.1488 - val_categorical_accuracy: 0.6667
# Epoch 120/1500
# 1/1 [==============================] - 0s 419ms/step - loss: 0.5724 - categorical_accuracy: 0.7500 - val_loss: 1.2046 - val_categorical_accuracy: 0.6190
# Epoch 121/1500
# 1/1 [==============================] - 1s 697ms/step - loss: 0.6686 - categorical_accuracy: 0.7500 - val_loss: 1.1500 - val_categorical_accuracy: 0.6667
# Epoch 122/1500
# 1/1 [==============================] - 0s 432ms/step - loss: 0.7247 - categorical_accuracy: 0.8000 - val_loss: 1.0133 - val_categorical_accuracy: 0.7619
# Epoch 123/1500
# 1/1 [==============================] - 1s 716ms/step - loss: 0.4493 - categorical_accuracy: 0.8281 - val_loss: 1.0793 - val_categorical_accuracy: 0.7143
# Epoch 124/1500
# 1/1 [==============================] - 0s 419ms/step - loss: 0.6450 - categorical_accuracy: 0.6500 - val_loss: 1.0701 - val_categorical_accuracy: 0.7143
# Epoch 125/1500
# 1/1 [==============================] - 1s 626ms/step - loss: 0.4505 - categorical_accuracy: 0.8594 - val_loss: 1.1176 - val_categorical_accuracy: 0.7143
# Epoch 126/1500
# 1/1 [==============================] - 0s 390ms/step - loss: 0.6389 - categorical_accuracy: 0.7000 - val_loss: 1.1123 - val_categorical_accuracy: 0.6667
# Epoch 127/1500
# 1/1 [==============================] - 1s 659ms/step - loss: 0.5416 - categorical_accuracy: 0.8281 - val_loss: 1.1052 - val_categorical_accuracy: 0.7143
# Epoch 128/1500
# 1/1 [==============================] - 0s 395ms/step - loss: 0.4820 - categorical_accuracy: 0.8000 - val_loss: 1.1378 - val_categorical_accuracy: 0.6667
# Epoch 129/1500
# 1/1 [==============================] - 1s 672ms/step - loss: 0.6235 - categorical_accuracy: 0.8125 - val_loss: 1.1250 - val_categorical_accuracy: 0.6667
# Epoch 130/1500
# 1/1 [==============================] - 0s 407ms/step - loss: 0.6899 - categorical_accuracy: 0.7500 - val_loss: 1.1129 - val_categorical_accuracy: 0.7143
# Epoch 131/1500
# 1/1 [==============================] - 1s 661ms/step - loss: 0.5229 - categorical_accuracy: 0.7969 - val_loss: 1.0882 - val_categorical_accuracy: 0.6190
# Epoch 132/1500
# 1/1 [==============================] - 0s 432ms/step - loss: 0.2097 - categorical_accuracy: 0.9500 - val_loss: 1.0932 - val_categorical_accuracy: 0.6190
# Epoch 133/1500
# 1/1 [==============================] - 1s 629ms/step - loss: 0.6387 - categorical_accuracy: 0.7812 - val_loss: 1.0536 - val_categorical_accuracy: 0.6190
# Epoch 134/1500
# 1/1 [==============================] - 0s 486ms/step - loss: 0.3443 - categorical_accuracy: 0.9000 - val_loss: 1.1606 - val_categorical_accuracy: 0.6667
# Epoch 135/1500
# 1/1 [==============================] - 1s 914ms/step - loss: 0.4482 - categorical_accuracy: 0.8125 - val_loss: 1.4023 - val_categorical_accuracy: 0.6190
# Epoch 136/1500
# 1/1 [==============================] - 1s 524ms/step - loss: 0.5284 - categorical_accuracy: 0.8000 - val_loss: 1.1367 - val_categorical_accuracy: 0.6667
# Epoch 137/1500
# 1/1 [==============================] - 1s 785ms/step - loss: 0.6193 - categorical_accuracy: 0.7344 - val_loss: 1.1385 - val_categorical_accuracy: 0.7143
# Epoch 138/1500
# 1/1 [==============================] - 0s 495ms/step - loss: 0.3961 - categorical_accuracy: 0.8500 - val_loss: 1.1207 - val_categorical_accuracy: 0.7143
# Epoch 139/1500
# 1/1 [==============================] - 1s 720ms/step - loss: 0.4978 - categorical_accuracy: 0.7812 - val_loss: 1.1713 - val_categorical_accuracy: 0.6667
# Epoch 140/1500
# 1/1 [==============================] - 0s 471ms/step - loss: 0.2015 - categorical_accuracy: 0.9000 - val_loss: 1.1328 - val_categorical_accuracy: 0.7143
# Epoch 141/1500
# 1/1 [==============================] - 1s 716ms/step - loss: 0.4648 - categorical_accuracy: 0.7812 - val_loss: 1.0663 - val_categorical_accuracy: 0.7619
# Epoch 142/1500
# 1/1 [==============================] - 0s 447ms/step - loss: 0.6199 - categorical_accuracy: 0.8000 - val_loss: 1.1508 - val_categorical_accuracy: 0.5714
# Epoch 143/1500
# 1/1 [==============================] - 1s 668ms/step - loss: 0.5490 - categorical_accuracy: 0.8125 - val_loss: 1.1118 - val_categorical_accuracy: 0.6667
# Epoch 144/1500
# 1/1 [==============================] - 1s 575ms/step - loss: 0.2374 - categorical_accuracy: 0.8500 - val_loss: 1.1045 - val_categorical_accuracy: 0.6667
# Epoch 145/1500
# 1/1 [==============================] - 1s 684ms/step - loss: 0.4342 - categorical_accuracy: 0.8125 - val_loss: 1.1573 - val_categorical_accuracy: 0.7143
# Epoch 146/1500
# 1/1 [==============================] - 1s 576ms/step - loss: 0.4331 - categorical_accuracy: 0.8000 - val_loss: 1.1134 - val_categorical_accuracy: 0.7143
# Epoch 147/1500
# 1/1 [==============================] - 1s 785ms/step - loss: 0.3099 - categorical_accuracy: 0.9219 - val_loss: 1.1295 - val_categorical_accuracy: 0.6667
# Epoch 148/1500
# 1/1 [==============================] - 1s 705ms/step - loss: 0.5222 - categorical_accuracy: 0.7500 - val_loss: 1.1862 - val_categorical_accuracy: 0.6667
# Epoch 149/1500
# 1/1 [==============================] - 1s 626ms/step - loss: 0.5062 - categorical_accuracy: 0.8438 - val_loss: 1.1710 - val_categorical_accuracy: 0.7143
# Epoch 150/1500
# 1/1 [==============================] - 0s 389ms/step - loss: 0.3373 - categorical_accuracy: 0.9000 - val_loss: 1.3010 - val_categorical_accuracy: 0.6190
# Epoch 151/1500
# 1/1 [==============================] - 1s 606ms/step - loss: 0.3771 - categorical_accuracy: 0.8594 - val_loss: 1.2830 - val_categorical_accuracy: 0.6667
# Epoch 152/1500
# 1/1 [==============================] - 0s 392ms/step - loss: 0.3371 - categorical_accuracy: 0.9500 - val_loss: 1.3562 - val_categorical_accuracy: 0.6667
# Epoch 153/1500
# 1/1 [==============================] - 1s 620ms/step - loss: 0.5597 - categorical_accuracy: 0.8281 - val_loss: 1.3000 - val_categorical_accuracy: 0.6667
# Epoch 154/1500
# 1/1 [==============================] - 0s 452ms/step - loss: 0.3386 - categorical_accuracy: 0.8500 - val_loss: 1.4920 - val_categorical_accuracy: 0.6667
# Epoch 155/1500
# 1/1 [==============================] - 1s 642ms/step - loss: 0.4358 - categorical_accuracy: 0.8750 - val_loss: 1.3401 - val_categorical_accuracy: 0.7143
# Epoch 156/1500
# 1/1 [==============================] - 0s 444ms/step - loss: 0.6208 - categorical_accuracy: 0.7000 - val_loss: 1.4429 - val_categorical_accuracy: 0.7619
# Epoch 157/1500
# 1/1 [==============================] - 1s 608ms/step - loss: 0.5100 - categorical_accuracy: 0.8750 - val_loss: 1.4017 - val_categorical_accuracy: 0.7143
# Epoch 158/1500
# 1/1 [==============================] - 0s 382ms/step - loss: 0.4513 - categorical_accuracy: 0.8000 - val_loss: 1.8934 - val_categorical_accuracy: 0.6190
# Epoch 159/1500
# 1/1 [==============================] - 1s 588ms/step - loss: 0.5405 - categorical_accuracy: 0.8125 - val_loss: 1.6592 - val_categorical_accuracy: 0.6667
# Epoch 160/1500
# 1/1 [==============================] - 0s 441ms/step - loss: 0.4545 - categorical_accuracy: 0.8500 - val_loss: 1.7348 - val_categorical_accuracy: 0.6190
# Epoch 161/1500
# 1/1 [==============================] - 1s 676ms/step - loss: 0.5302 - categorical_accuracy: 0.8906 - val_loss: 1.7273 - val_categorical_accuracy: 0.6667
# Epoch 162/1500
# 1/1 [==============================] - 0s 481ms/step - loss: 0.2630 - categorical_accuracy: 0.9000 - val_loss: 1.7534 - val_categorical_accuracy: 0.6190
# Epoch 163/1500
# 1/1 [==============================] - 1s 700ms/step - loss: 0.4764 - categorical_accuracy: 0.8125 - val_loss: 1.7082 - val_categorical_accuracy: 0.6667
# Epoch 164/1500
# 1/1 [==============================] - 0s 498ms/step - loss: 0.3339 - categorical_accuracy: 0.8500 - val_loss: 1.6922 - val_categorical_accuracy: 0.6190
# Epoch 165/1500
# 1/1 [==============================] - 1s 666ms/step - loss: 0.3768 - categorical_accuracy: 0.9062 - val_loss: 1.5376 - val_categorical_accuracy: 0.7143
# Epoch 166/1500
# 1/1 [==============================] - 0s 430ms/step - loss: 0.4094 - categorical_accuracy: 0.9000 - val_loss: 1.4300 - val_categorical_accuracy: 0.6667
# Epoch 167/1500
# 1/1 [==============================] - 1s 637ms/step - loss: 0.2417 - categorical_accuracy: 0.9062 - val_loss: 1.3806 - val_categorical_accuracy: 0.7143
# Epoch 168/1500
# 1/1 [==============================] - 0s 427ms/step - loss: 0.5430 - categorical_accuracy: 0.9000 - val_loss: 1.2888 - val_categorical_accuracy: 0.6667
# Epoch 169/1500
# 1/1 [==============================] - 1s 638ms/step - loss: 0.3522 - categorical_accuracy: 0.8750 - val_loss: 1.2369 - val_categorical_accuracy: 0.6667
# Epoch 170/1500
# 1/1 [==============================] - 0s 425ms/step - loss: 0.4072 - categorical_accuracy: 0.8500 - val_loss: 1.1610 - val_categorical_accuracy: 0.6667
# Epoch 171/1500
# 1/1 [==============================] - 1s 654ms/step - loss: 0.3536 - categorical_accuracy: 0.8750 - val_loss: 1.0762 - val_categorical_accuracy: 0.6190
# Epoch 172/1500
# 1/1 [==============================] - 0s 431ms/step - loss: 0.4235 - categorical_accuracy: 0.8500 - val_loss: 1.1744 - val_categorical_accuracy: 0.6190
# Epoch 173/1500
# 1/1 [==============================] - 1s 622ms/step - loss: 0.4452 - categorical_accuracy: 0.8750 - val_loss: 1.0540 - val_categorical_accuracy: 0.6667
# Epoch 174/1500
# 1/1 [==============================] - 0s 446ms/step - loss: 0.3950 - categorical_accuracy: 0.8000 - val_loss: 0.8733 - val_categorical_accuracy: 0.7619
# Epoch 175/1500
# 1/1 [==============================] - 1s 719ms/step - loss: 0.4093 - categorical_accuracy: 0.8594 - val_loss: 0.8849 - val_categorical_accuracy: 0.7143
# Epoch 176/1500
# 1/1 [==============================] - 0s 420ms/step - loss: 0.3553 - categorical_accuracy: 0.9000 - val_loss: 0.8371 - val_categorical_accuracy: 0.8095
# Epoch 177/1500
# 1/1 [==============================] - 1s 647ms/step - loss: 0.2556 - categorical_accuracy: 0.9219 - val_loss: 0.8905 - val_categorical_accuracy: 0.8571
# Epoch 178/1500
# 1/1 [==============================] - 0s 414ms/step - loss: 0.2903 - categorical_accuracy: 0.9000 - val_loss: 1.0112 - val_categorical_accuracy: 0.7143
# Epoch 179/1500
# 1/1 [==============================] - 1s 580ms/step - loss: 0.3464 - categorical_accuracy: 0.8906 - val_loss: 1.0444 - val_categorical_accuracy: 0.7143
# Epoch 180/1500
# 1/1 [==============================] - 0s 398ms/step - loss: 0.4893 - categorical_accuracy: 0.8500 - val_loss: 1.1893 - val_categorical_accuracy: 0.7143
# Epoch 181/1500
# 1/1 [==============================] - 1s 631ms/step - loss: 0.4071 - categorical_accuracy: 0.8438 - val_loss: 1.1024 - val_categorical_accuracy: 0.8095
# Epoch 182/1500
# 1/1 [==============================] - 0s 481ms/step - loss: 0.1081 - categorical_accuracy: 1.0000 - val_loss: 1.1758 - val_categorical_accuracy: 0.7619
# Epoch 183/1500
# 1/1 [==============================] - 1s 678ms/step - loss: 0.3035 - categorical_accuracy: 0.9219 - val_loss: 1.2445 - val_categorical_accuracy: 0.7619
# Epoch 184/1500
# 1/1 [==============================] - 0s 435ms/step - loss: 0.3573 - categorical_accuracy: 0.8000 - val_loss: 1.1836 - val_categorical_accuracy: 0.7143
# Epoch 185/1500
# 1/1 [==============================] - 1s 691ms/step - loss: 0.2449 - categorical_accuracy: 0.9062 - val_loss: 1.0883 - val_categorical_accuracy: 0.8095
# Epoch 186/1500
# 1/1 [==============================] - 0s 473ms/step - loss: 0.3727 - categorical_accuracy: 0.9000 - val_loss: 1.4149 - val_categorical_accuracy: 0.7143
# Epoch 187/1500
# 1/1 [==============================] - 1s 628ms/step - loss: 0.3941 - categorical_accuracy: 0.8594 - val_loss: 1.2163 - val_categorical_accuracy: 0.7143
# Epoch 188/1500
# 1/1 [==============================] - 0s 411ms/step - loss: 0.2548 - categorical_accuracy: 0.9000 - val_loss: 0.9912 - val_categorical_accuracy: 0.8571
# Epoch 189/1500
# 1/1 [==============================] - 1s 693ms/step - loss: 0.1876 - categorical_accuracy: 0.9375 - val_loss: 1.0094 - val_categorical_accuracy: 0.8571
# Epoch 190/1500
# 1/1 [==============================] - 0s 445ms/step - loss: 0.3048 - categorical_accuracy: 0.8500 - val_loss: 0.9873 - val_categorical_accuracy: 0.8095
# Epoch 191/1500
# 1/1 [==============================] - 1s 626ms/step - loss: 0.2397 - categorical_accuracy: 0.9062 - val_loss: 1.0936 - val_categorical_accuracy: 0.7619
# Epoch 192/1500
# 1/1 [==============================] - 0s 419ms/step - loss: 0.1530 - categorical_accuracy: 0.9500 - val_loss: 1.1854 - val_categorical_accuracy: 0.8095
# Epoch 193/1500
# 1/1 [==============================] - 1s 646ms/step - loss: 0.2269 - categorical_accuracy: 0.9375 - val_loss: 1.2974 - val_categorical_accuracy: 0.7619
# Epoch 194/1500
# 1/1 [==============================] - 0s 409ms/step - loss: 0.4026 - categorical_accuracy: 0.9000 - val_loss: 1.4627 - val_categorical_accuracy: 0.7619
# Epoch 195/1500
# 1/1 [==============================] - 1s 637ms/step - loss: 0.3332 - categorical_accuracy: 0.9062 - val_loss: 1.5778 - val_categorical_accuracy: 0.7619
# Epoch 196/1500
# 1/1 [==============================] - 0s 408ms/step - loss: 0.3341 - categorical_accuracy: 0.8500 - val_loss: 1.6213 - val_categorical_accuracy: 0.7619
# Epoch 197/1500
# 1/1 [==============================] - 1s 688ms/step - loss: 0.2937 - categorical_accuracy: 0.9375 - val_loss: 1.5493 - val_categorical_accuracy: 0.7619
# Epoch 198/1500
# 1/1 [==============================] - 0s 403ms/step - loss: 0.2761 - categorical_accuracy: 0.9000 - val_loss: 1.6524 - val_categorical_accuracy: 0.7143
# Epoch 199/1500
# 1/1 [==============================] - 1s 577ms/step - loss: 0.3011 - categorical_accuracy: 0.8750 - val_loss: 1.6771 - val_categorical_accuracy: 0.7619
# Epoch 200/1500
# 1/1 [==============================] - 0s 427ms/step - loss: 0.4225 - categorical_accuracy: 0.9000 - val_loss: 1.8187 - val_categorical_accuracy: 0.7143
# Epoch 201/1500
# 1/1 [==============================] - 1s 571ms/step - loss: 0.4836 - categorical_accuracy: 0.8281 - val_loss: 1.4447 - val_categorical_accuracy: 0.7619
# Epoch 202/1500
# 1/1 [==============================] - 0s 393ms/step - loss: 0.0562 - categorical_accuracy: 1.0000 - val_loss: 1.4196 - val_categorical_accuracy: 0.7619
# Epoch 203/1500
# 1/1 [==============================] - 1s 571ms/step - loss: 0.3813 - categorical_accuracy: 0.9219 - val_loss: 1.2745 - val_categorical_accuracy: 0.8095
# Epoch 204/1500
# 1/1 [==============================] - 0s 365ms/step - loss: 0.2017 - categorical_accuracy: 0.9500 - val_loss: 1.2154 - val_categorical_accuracy: 0.7143
# Epoch 205/1500
# 1/1 [==============================] - 1s 613ms/step - loss: 0.3100 - categorical_accuracy: 0.8906 - val_loss: 1.1981 - val_categorical_accuracy: 0.7143
# Epoch 206/1500
# 1/1 [==============================] - 0s 392ms/step - loss: 0.2035 - categorical_accuracy: 0.9500 - val_loss: 1.2462 - val_categorical_accuracy: 0.7143
# Epoch 207/1500
# 1/1 [==============================] - 1s 666ms/step - loss: 0.1726 - categorical_accuracy: 0.9688 - val_loss: 1.2210 - val_categorical_accuracy: 0.7619
# Epoch 208/1500
# 1/1 [==============================] - 0s 382ms/step - loss: 0.3952 - categorical_accuracy: 0.9000 - val_loss: 1.2398 - val_categorical_accuracy: 0.7619
# Epoch 209/1500
# 1/1 [==============================] - 1s 574ms/step - loss: 0.2698 - categorical_accuracy: 0.9688 - val_loss: 1.3063 - val_categorical_accuracy: 0.7619
# Epoch 210/1500
# 1/1 [==============================] - 0s 389ms/step - loss: 0.1583 - categorical_accuracy: 0.9500 - val_loss: 1.4659 - val_categorical_accuracy: 0.7143
# Epoch 211/1500
# 1/1 [==============================] - 1s 607ms/step - loss: 0.2927 - categorical_accuracy: 0.9219 - val_loss: 1.4519 - val_categorical_accuracy: 0.6667
# Epoch 212/1500
# 1/1 [==============================] - 0s 387ms/step - loss: 0.1861 - categorical_accuracy: 0.9500 - val_loss: 1.4172 - val_categorical_accuracy: 0.6667
# Epoch 213/1500
# 1/1 [==============================] - 1s 576ms/step - loss: 0.2024 - categorical_accuracy: 0.9375 - val_loss: 1.4624 - val_categorical_accuracy: 0.7143
# Epoch 214/1500
# 1/1 [==============================] - 0s 422ms/step - loss: 0.1888 - categorical_accuracy: 0.9000 - val_loss: 1.5789 - val_categorical_accuracy: 0.6667
# Epoch 215/1500
# 1/1 [==============================] - 1s 636ms/step - loss: 0.4435 - categorical_accuracy: 0.8906 - val_loss: 1.4459 - val_categorical_accuracy: 0.6667
# Epoch 216/1500
# 1/1 [==============================] - 0s 439ms/step - loss: 0.1951 - categorical_accuracy: 0.9000 - val_loss: 1.6083 - val_categorical_accuracy: 0.7143
# Epoch 217/1500
# 1/1 [==============================] - 1s 668ms/step - loss: 0.1979 - categorical_accuracy: 0.9375 - val_loss: 1.6834 - val_categorical_accuracy: 0.6667
# Epoch 218/1500
# 1/1 [==============================] - 0s 429ms/step - loss: 0.2813 - categorical_accuracy: 0.9000 - val_loss: 1.4992 - val_categorical_accuracy: 0.7619
# Epoch 219/1500
# 1/1 [==============================] - 1s 646ms/step - loss: 0.1493 - categorical_accuracy: 0.9531 - val_loss: 1.4489 - val_categorical_accuracy: 0.7619
# Epoch 220/1500
# 1/1 [==============================] - 1s 532ms/step - loss: 0.1700 - categorical_accuracy: 0.9000 - val_loss: 1.5630 - val_categorical_accuracy: 0.6667
# Epoch 221/1500
# 1/1 [==============================] - 1s 603ms/step - loss: 0.3180 - categorical_accuracy: 0.9062 - val_loss: 1.3742 - val_categorical_accuracy: 0.7619
# Epoch 222/1500
# 1/1 [==============================] - 0s 401ms/step - loss: 0.1224 - categorical_accuracy: 1.0000 - val_loss: 1.3672 - val_categorical_accuracy: 0.8095
# Epoch 223/1500
# 1/1 [==============================] - 1s 574ms/step - loss: 0.2407 - categorical_accuracy: 0.9219 - val_loss: 1.3147 - val_categorical_accuracy: 0.8095
# Epoch 224/1500
# 1/1 [==============================] - 0s 379ms/step - loss: 0.1277 - categorical_accuracy: 1.0000 - val_loss: 1.2442 - val_categorical_accuracy: 0.7619
# Epoch 225/1500
# 1/1 [==============================] - 1s 676ms/step - loss: 0.2560 - categorical_accuracy: 0.9219 - val_loss: 1.2274 - val_categorical_accuracy: 0.7619
# Epoch 226/1500
# 1/1 [==============================] - 0s 427ms/step - loss: 0.0563 - categorical_accuracy: 1.0000 - val_loss: 1.2133 - val_categorical_accuracy: 0.7619
# Epoch 227/1500
# 1/1 [==============================] - 1s 602ms/step - loss: 0.1913 - categorical_accuracy: 0.9531 - val_loss: 1.2225 - val_categorical_accuracy: 0.7619
# Epoch 228/1500
# 1/1 [==============================] - 0s 405ms/step - loss: 0.0943 - categorical_accuracy: 1.0000 - val_loss: 1.2545 - val_categorical_accuracy: 0.7619
# Epoch 229/1500
# 1/1 [==============================] - 1s 547ms/step - loss: 0.1426 - categorical_accuracy: 0.9688 - val_loss: 1.2615 - val_categorical_accuracy: 0.7619
# Epoch 230/1500
# 1/1 [==============================] - 0s 393ms/step - loss: 0.0651 - categorical_accuracy: 1.0000 - val_loss: 1.2571 - val_categorical_accuracy: 0.7619
# Epoch 231/1500
# 1/1 [==============================] - 1s 591ms/step - loss: 0.1122 - categorical_accuracy: 0.9844 - val_loss: 1.2941 - val_categorical_accuracy: 0.7619
# Epoch 232/1500
# 1/1 [==============================] - 0s 402ms/step - loss: 0.2162 - categorical_accuracy: 0.9500 - val_loss: 1.3090 - val_categorical_accuracy: 0.7619
# Epoch 233/1500
# 1/1 [==============================] - 1s 588ms/step - loss: 0.1478 - categorical_accuracy: 0.9688 - val_loss: 1.3354 - val_categorical_accuracy: 0.7619
# Epoch 234/1500
# 1/1 [==============================] - 0s 385ms/step - loss: 0.1476 - categorical_accuracy: 0.9000 - val_loss: 1.3390 - val_categorical_accuracy: 0.8095
# Epoch 235/1500
# 1/1 [==============================] - 1s 624ms/step - loss: 0.2017 - categorical_accuracy: 0.9375 - val_loss: 1.3061 - val_categorical_accuracy: 0.8095
# Epoch 236/1500
# 1/1 [==============================] - 0s 366ms/step - loss: 0.0844 - categorical_accuracy: 1.0000 - val_loss: 1.2671 - val_categorical_accuracy: 0.8095
# Epoch 237/1500
# 1/1 [==============================] - 1s 559ms/step - loss: 0.1163 - categorical_accuracy: 0.9844 - val_loss: 1.2571 - val_categorical_accuracy: 0.8095
# Epoch 238/1500
# 1/1 [==============================] - 0s 369ms/step - loss: 0.3420 - categorical_accuracy: 0.9500 - val_loss: 1.8420 - val_categorical_accuracy: 0.7143
# Epoch 239/1500
# 1/1 [==============================] - 1s 600ms/step - loss: 0.1997 - categorical_accuracy: 0.9375 - val_loss: 1.8378 - val_categorical_accuracy: 0.7143
# Epoch 240/1500
# 1/1 [==============================] - 0s 407ms/step - loss: 0.7729 - categorical_accuracy: 0.9000 - val_loss: 1.3068 - val_categorical_accuracy: 0.7619
# Epoch 241/1500
# 1/1 [==============================] - 1s 624ms/step - loss: 0.1334 - categorical_accuracy: 0.9844 - val_loss: 1.4254 - val_categorical_accuracy: 0.7619
# Epoch 242/1500
# 1/1 [==============================] - 0s 367ms/step - loss: 0.2878 - categorical_accuracy: 0.9500 - val_loss: 1.4420 - val_categorical_accuracy: 0.7619
# Epoch 243/1500
# 1/1 [==============================] - 1s 572ms/step - loss: 0.1415 - categorical_accuracy: 0.9688 - val_loss: 1.3807 - val_categorical_accuracy: 0.7619
# Epoch 244/1500
# 1/1 [==============================] - 0s 435ms/step - loss: 0.4797 - categorical_accuracy: 0.9000 - val_loss: 1.2633 - val_categorical_accuracy: 0.7619
# Epoch 245/1500
# 1/1 [==============================] - 1s 687ms/step - loss: 0.1582 - categorical_accuracy: 0.9531 - val_loss: 1.3340 - val_categorical_accuracy: 0.7619
# Epoch 246/1500
# 1/1 [==============================] - 0s 375ms/step - loss: 0.1887 - categorical_accuracy: 0.9000 - val_loss: 1.5533 - val_categorical_accuracy: 0.7143
# Epoch 247/1500
# 1/1 [==============================] - 1s 624ms/step - loss: 0.2220 - categorical_accuracy: 0.9219 - val_loss: 1.5400 - val_categorical_accuracy: 0.7143
# Epoch 248/1500
# 1/1 [==============================] - 0s 373ms/step - loss: 0.0763 - categorical_accuracy: 1.0000 - val_loss: 1.6323 - val_categorical_accuracy: 0.7619
# Epoch 249/1500
# 1/1 [==============================] - 1s 569ms/step - loss: 0.1141 - categorical_accuracy: 0.9688 - val_loss: 1.6614 - val_categorical_accuracy: 0.7619
# Epoch 250/1500
# 1/1 [==============================] - 0s 404ms/step - loss: 0.3126 - categorical_accuracy: 0.9000 - val_loss: 1.6174 - val_categorical_accuracy: 0.7143
# Epoch 251/1500
# 1/1 [==============================] - 1s 616ms/step - loss: 0.0849 - categorical_accuracy: 1.0000 - val_loss: 1.6227 - val_categorical_accuracy: 0.7143
# Epoch 252/1500
# 1/1 [==============================] - 0s 416ms/step - loss: 0.1396 - categorical_accuracy: 0.9500 - val_loss: 1.5880 - val_categorical_accuracy: 0.7143
# Epoch 253/1500
# 1/1 [==============================] - 1s 587ms/step - loss: 0.3058 - categorical_accuracy: 0.9062 - val_loss: 1.4769 - val_categorical_accuracy: 0.7619
# Epoch 254/1500
# 1/1 [==============================] - 0s 425ms/step - loss: 0.1285 - categorical_accuracy: 1.0000 - val_loss: 1.4192 - val_categorical_accuracy: 0.7619
# Epoch 255/1500
# 1/1 [==============================] - 1s 577ms/step - loss: 0.1941 - categorical_accuracy: 0.9375 - val_loss: 1.2715 - val_categorical_accuracy: 0.7619
# Epoch 256/1500
# 1/1 [==============================] - 0s 382ms/step - loss: 0.4199 - categorical_accuracy: 0.9500 - val_loss: 1.4107 - val_categorical_accuracy: 0.7619
# Epoch 257/1500
# 1/1 [==============================] - 1s 646ms/step - loss: 0.1685 - categorical_accuracy: 0.9531 - val_loss: 1.3219 - val_categorical_accuracy: 0.7619
# Epoch 258/1500
# 1/1 [==============================] - 1s 522ms/step - loss: 0.1937 - categorical_accuracy: 0.9500 - val_loss: 1.3619 - val_categorical_accuracy: 0.7619
# Epoch 259/1500
# 1/1 [==============================] - 1s 593ms/step - loss: 0.2934 - categorical_accuracy: 0.9062 - val_loss: 1.2692 - val_categorical_accuracy: 0.7619
# Epoch 260/1500
# 1/1 [==============================] - 0s 396ms/step - loss: 0.0812 - categorical_accuracy: 1.0000 - val_loss: 1.2735 - val_categorical_accuracy: 0.7143
# Epoch 261/1500
# 1/1 [==============================] - 1s 631ms/step - loss: 0.1404 - categorical_accuracy: 0.9844 - val_loss: 1.2787 - val_categorical_accuracy: 0.7143
# Epoch 262/1500
# 1/1 [==============================] - 0s 370ms/step - loss: 0.7764 - categorical_accuracy: 0.7500 - val_loss: 1.5493 - val_categorical_accuracy: 0.7619
# Epoch 263/1500
# 1/1 [==============================] - 1s 581ms/step - loss: 0.4805 - categorical_accuracy: 0.9062 - val_loss: 1.2310 - val_categorical_accuracy: 0.7619
# Epoch 264/1500
# 1/1 [==============================] - 0s 455ms/step - loss: 0.3798 - categorical_accuracy: 0.9000 - val_loss: 1.3416 - val_categorical_accuracy: 0.7619
# Epoch 265/1500
# 1/1 [==============================] - 1s 581ms/step - loss: 0.2306 - categorical_accuracy: 0.9219 - val_loss: 1.2791 - val_categorical_accuracy: 0.7619
# Epoch 266/1500
# 1/1 [==============================] - 0s 378ms/step - loss: 0.0840 - categorical_accuracy: 1.0000 - val_loss: 1.3063 - val_categorical_accuracy: 0.8095
# Epoch 267/1500
# 1/1 [==============================] - 1s 583ms/step - loss: 0.2792 - categorical_accuracy: 0.9219 - val_loss: 1.3720 - val_categorical_accuracy: 0.7619
# Epoch 268/1500
# 1/1 [==============================] - 0s 364ms/step - loss: 0.1321 - categorical_accuracy: 1.0000 - val_loss: 1.4325 - val_categorical_accuracy: 0.7619
# Epoch 269/1500
# 1/1 [==============================] - 1s 577ms/step - loss: 0.1753 - categorical_accuracy: 0.9531 - val_loss: 1.4514 - val_categorical_accuracy: 0.7619
# Epoch 270/1500
# 1/1 [==============================] - 0s 378ms/step - loss: 0.0560 - categorical_accuracy: 1.0000 - val_loss: 1.4816 - val_categorical_accuracy: 0.7619
# Epoch 271/1500
# 1/1 [==============================] - 1s 592ms/step - loss: 0.1350 - categorical_accuracy: 0.9688 - val_loss: 1.5722 - val_categorical_accuracy: 0.7619
# Epoch 272/1500
# 1/1 [==============================] - 0s 387ms/step - loss: 0.2614 - categorical_accuracy: 0.9500 - val_loss: 1.4551 - val_categorical_accuracy: 0.8095
# Epoch 273/1500
# 1/1 [==============================] - 1s 592ms/step - loss: 0.4219 - categorical_accuracy: 0.8594 - val_loss: 1.5068 - val_categorical_accuracy: 0.7143
# Epoch 274/1500
# 1/1 [==============================] - 0s 384ms/step - loss: 0.1265 - categorical_accuracy: 0.9500 - val_loss: 1.6682 - val_categorical_accuracy: 0.7143
# Epoch 275/1500
# 1/1 [==============================] - 1s 616ms/step - loss: 0.2311 - categorical_accuracy: 0.9375 - val_loss: 1.6305 - val_categorical_accuracy: 0.7143
# Epoch 276/1500
# 1/1 [==============================] - 0s 400ms/step - loss: 0.0949 - categorical_accuracy: 1.0000 - val_loss: 1.6765 - val_categorical_accuracy: 0.7143
# Epoch 277/1500
# 1/1 [==============================] - 1s 603ms/step - loss: 0.2755 - categorical_accuracy: 0.9219 - val_loss: 1.6103 - val_categorical_accuracy: 0.6667
# Epoch 278/1500
# 1/1 [==============================] - 0s 379ms/step - loss: 0.6520 - categorical_accuracy: 0.7500 - val_loss: 2.5769 - val_categorical_accuracy: 0.7143
# Epoch 279/1500
# 1/1 [==============================] - 1s 585ms/step - loss: 0.5426 - categorical_accuracy: 0.8281 - val_loss: 2.3694 - val_categorical_accuracy: 0.7143
# Epoch 280/1500
# 1/1 [==============================] - 0s 371ms/step - loss: 0.5948 - categorical_accuracy: 0.9000 - val_loss: 1.9478 - val_categorical_accuracy: 0.7143
# Epoch 281/1500
# 1/1 [==============================] - 1s 607ms/step - loss: 0.2833 - categorical_accuracy: 0.9375 - val_loss: 1.7924 - val_categorical_accuracy: 0.7143
# Epoch 282/1500
# 1/1 [==============================] - 0s 387ms/step - loss: 0.2188 - categorical_accuracy: 0.9500 - val_loss: 1.6070 - val_categorical_accuracy: 0.7143
# Epoch 283/1500
# 1/1 [==============================] - 1s 587ms/step - loss: 0.1321 - categorical_accuracy: 0.9844 - val_loss: 1.5248 - val_categorical_accuracy: 0.7143
# Epoch 284/1500
# 1/1 [==============================] - 0s 415ms/step - loss: 0.1532 - categorical_accuracy: 0.9500 - val_loss: 1.5009 - val_categorical_accuracy: 0.8095
# Epoch 285/1500
# 1/1 [==============================] - 1s 618ms/step - loss: 0.1954 - categorical_accuracy: 0.9531 - val_loss: 1.5417 - val_categorical_accuracy: 0.8095
# Epoch 286/1500
# 1/1 [==============================] - 0s 378ms/step - loss: 0.1801 - categorical_accuracy: 0.9500 - val_loss: 1.4456 - val_categorical_accuracy: 0.8095
# Epoch 287/1500
# ...
# Epoch 1407/1500
# 1/1 [==============================] - 1s 584ms/step - loss: 0.0658 - categorical_accuracy: 0.9844 - val_loss: 1.6763 - val_categorical_accuracy: 0.7143
# Epoch 1408/1500
# 1/1 [==============================] - 0s 373ms/step - loss: 0.0445 - categorical_accuracy: 1.0000 - val_loss: 1.6224 - val_categorical_accuracy: 0.7143
# Epoch 1409/1500
# 1/1 [==============================] - 1s 584ms/step - loss: 0.0497 - categorical_accuracy: 1.0000 - val_loss: 1.5332 - val_categorical_accuracy: 0.7143
# Epoch 1410/1500
# 1/1 [==============================] - 0s 365ms/step - loss: 0.0638 - categorical_accuracy: 1.0000 - val_loss: 1.4458 - val_categorical_accuracy: 0.7143
# Epoch 1411/1500
# 1/1 [==============================] - 1s 585ms/step - loss: 0.0561 - categorical_accuracy: 1.0000 - val_loss: 1.4177 - val_categorical_accuracy: 0.7143
# Epoch 1412/1500
# 1/1 [==============================] - 0s 384ms/step - loss: 0.0428 - categorical_accuracy: 1.0000 - val_loss: 1.3766 - val_categorical_accuracy: 0.7619
# Epoch 1413/1500
# 1/1 [==============================] - 1s 598ms/step - loss: 0.0955 - categorical_accuracy: 0.9844 - val_loss: 1.4313 - val_categorical_accuracy: 0.7619
# Epoch 1414/1500
# 1/1 [==============================] - 0s 367ms/step - loss: 0.0422 - categorical_accuracy: 1.0000 - val_loss: 1.4633 - val_categorical_accuracy: 0.7619
# Epoch 1415/1500
# 1/1 [==============================] - 1s 583ms/step - loss: 0.0838 - categorical_accuracy: 0.9844 - val_loss: 1.5018 - val_categorical_accuracy: 0.7619
# Epoch 1416/1500
# 1/1 [==============================] - 0s 381ms/step - loss: 0.0429 - categorical_accuracy: 1.0000 - val_loss: 1.5483 - val_categorical_accuracy: 0.7619
# Epoch 1417/1500
# 1/1 [==============================] - 1s 597ms/step - loss: 0.0465 - categorical_accuracy: 1.0000 - val_loss: 1.5898 - val_categorical_accuracy: 0.7143
# Epoch 1418/1500
# 1/1 [==============================] - 0s 366ms/step - loss: 0.0462 - categorical_accuracy: 1.0000 - val_loss: 1.6334 - val_categorical_accuracy: 0.7143
# Epoch 1419/1500
# 1/1 [==============================] - 1s 584ms/step - loss: 0.0753 - categorical_accuracy: 0.9844 - val_loss: 1.4937 - val_categorical_accuracy: 0.7143
# Epoch 1420/1500
# 1/1 [==============================] - 0s 366ms/step - loss: 0.0425 - categorical_accuracy: 1.0000 - val_loss: 1.4759 - val_categorical_accuracy: 0.6667
# Epoch 1421/1500
# 1/1 [==============================] - 1s 602ms/step - loss: 0.1844 - categorical_accuracy: 0.9688 - val_loss: 1.4910 - val_categorical_accuracy: 0.7143
# Epoch 1422/1500
# 1/1 [==============================] - 0s 377ms/step - loss: 0.0455 - categorical_accuracy: 1.0000 - val_loss: 1.5488 - val_categorical_accuracy: 0.7143
# Epoch 1423/1500
# 1/1 [==============================] - 1s 587ms/step - loss: 0.0822 - categorical_accuracy: 0.9844 - val_loss: 1.5440 - val_categorical_accuracy: 0.7619
# Epoch 1424/1500
# 1/1 [==============================] - 0s 367ms/step - loss: 0.0601 - categorical_accuracy: 1.0000 - val_loss: 1.6012 - val_categorical_accuracy: 0.8095
# Epoch 1425/1500
# 1/1 [==============================] - 1s 600ms/step - loss: 0.0468 - categorical_accuracy: 1.0000 - val_loss: 1.6905 - val_categorical_accuracy: 0.8095
# Epoch 1426/1500
# 1/1 [==============================] - 0s 363ms/step - loss: 0.5763 - categorical_accuracy: 0.9500 - val_loss: 2.0431 - val_categorical_accuracy: 0.7619
# Epoch 1427/1500
# 1/1 [==============================] - 1s 584ms/step - loss: 0.0440 - categorical_accuracy: 1.0000 - val_loss: 2.2139 - val_categorical_accuracy: 0.7143
# Epoch 1428/1500
# 1/1 [==============================] - 0s 365ms/step - loss: 0.0426 - categorical_accuracy: 1.0000 - val_loss: 2.3431 - val_categorical_accuracy: 0.7143
# Epoch 1429/1500
# 1/1 [==============================] - 1s 608ms/step - loss: 0.0473 - categorical_accuracy: 1.0000 - val_loss: 2.4515 - val_categorical_accuracy: 0.7143
# Epoch 1430/1500
# 1/1 [==============================] - 0s 376ms/step - loss: 0.1825 - categorical_accuracy: 0.9500 - val_loss: 2.4659 - val_categorical_accuracy: 0.7143
# Epoch 1431/1500
# 1/1 [==============================] - 1s 610ms/step - loss: 0.1110 - categorical_accuracy: 0.9688 - val_loss: 2.4651 - val_categorical_accuracy: 0.7143
# Epoch 1432/1500
# 1/1 [==============================] - 0s 388ms/step - loss: 0.0440 - categorical_accuracy: 1.0000 - val_loss: 2.5173 - val_categorical_accuracy: 0.7143
# Epoch 1433/1500
# 1/1 [==============================] - 1s 582ms/step - loss: 0.0862 - categorical_accuracy: 0.9688 - val_loss: 2.4023 - val_categorical_accuracy: 0.7143
# Epoch 1434/1500
# 1/1 [==============================] - 0s 383ms/step - loss: 0.0465 - categorical_accuracy: 1.0000 - val_loss: 2.3764 - val_categorical_accuracy: 0.7143
# Epoch 1435/1500
# 1/1 [==============================] - 1s 586ms/step - loss: 0.0976 - categorical_accuracy: 0.9688 - val_loss: 2.3106 - val_categorical_accuracy: 0.7143
# Epoch 1436/1500
# 1/1 [==============================] - 0s 366ms/step - loss: 0.0744 - categorical_accuracy: 1.0000 - val_loss: 2.2125 - val_categorical_accuracy: 0.7619
# Epoch 1437/1500
# 1/1 [==============================] - 1s 564ms/step - loss: 0.0656 - categorical_accuracy: 0.9844 - val_loss: 2.0881 - val_categorical_accuracy: 0.7619
# Epoch 1438/1500
# 1/1 [==============================] - 0s 366ms/step - loss: 0.0477 - categorical_accuracy: 1.0000 - val_loss: 1.9677 - val_categorical_accuracy: 0.7619
# Epoch 1439/1500
# 1/1 [==============================] - 1s 583ms/step - loss: 0.1085 - categorical_accuracy: 0.9844 - val_loss: 1.8570 - val_categorical_accuracy: 0.7619
# Epoch 1440/1500
# 1/1 [==============================] - 0s 367ms/step - loss: 0.0441 - categorical_accuracy: 1.0000 - val_loss: 1.8060 - val_categorical_accuracy: 0.8095
# Epoch 1441/1500
# 1/1 [==============================] - 1s 589ms/step - loss: 0.1265 - categorical_accuracy: 0.9844 - val_loss: 1.7922 - val_categorical_accuracy: 0.8095
# Epoch 1442/1500
# 1/1 [==============================] - 0s 383ms/step - loss: 0.0547 - categorical_accuracy: 1.0000 - val_loss: 1.7438 - val_categorical_accuracy: 0.8095
# Epoch 1443/1500
# 1/1 [==============================] - 1s 600ms/step - loss: 0.1121 - categorical_accuracy: 0.9688 - val_loss: 1.6709 - val_categorical_accuracy: 0.8095
# Epoch 1444/1500
# 1/1 [==============================] - 0s 382ms/step - loss: 0.0481 - categorical_accuracy: 1.0000 - val_loss: 1.6452 - val_categorical_accuracy: 0.8095
# Epoch 1445/1500
# 1/1 [==============================] - 1s 617ms/step - loss: 0.0536 - categorical_accuracy: 1.0000 - val_loss: 1.6115 - val_categorical_accuracy: 0.8095
# Epoch 1446/1500
# 1/1 [==============================] - 0s 366ms/step - loss: 0.0426 - categorical_accuracy: 1.0000 - val_loss: 1.5877 - val_categorical_accuracy: 0.8095
# Epoch 1447/1500
# 1/1 [==============================] - 1s 583ms/step - loss: 0.0457 - categorical_accuracy: 1.0000 - val_loss: 1.5639 - val_categorical_accuracy: 0.8095
# Epoch 1448/1500
# 1/1 [==============================] - 0s 368ms/step - loss: 0.0471 - categorical_accuracy: 1.0000 - val_loss: 1.5590 - val_categorical_accuracy: 0.8095
# Epoch 1449/1500
# 1/1 [==============================] - 1s 583ms/step - loss: 0.0441 - categorical_accuracy: 1.0000 - val_loss: 1.5540 - val_categorical_accuracy: 0.8095
# Epoch 1450/1500
# 1/1 [==============================] - 0s 368ms/step - loss: 0.0438 - categorical_accuracy: 1.0000 - val_loss: 1.5584 - val_categorical_accuracy: 0.8095
# Epoch 1451/1500
# 1/1 [==============================] - 1s 584ms/step - loss: 0.0448 - categorical_accuracy: 1.0000 - val_loss: 1.5638 - val_categorical_accuracy: 0.8095
# Epoch 1452/1500
# 1/1 [==============================] - 0s 381ms/step - loss: 0.0483 - categorical_accuracy: 1.0000 - val_loss: 1.5789 - val_categorical_accuracy: 0.8095
# Epoch 1453/1500
# 1/1 [==============================] - 1s 584ms/step - loss: 0.0953 - categorical_accuracy: 0.9844 - val_loss: 1.5837 - val_categorical_accuracy: 0.7619
# Epoch 1454/1500
# 1/1 [==============================] - 0s 382ms/step - loss: 0.0430 - categorical_accuracy: 1.0000 - val_loss: 1.5998 - val_categorical_accuracy: 0.7619
# Epoch 1455/1500
# 1/1 [==============================] - 1s 598ms/step - loss: 0.0646 - categorical_accuracy: 0.9844 - val_loss: 1.6145 - val_categorical_accuracy: 0.7619
# Epoch 1456/1500
# 1/1 [==============================] - 0s 368ms/step - loss: 0.0438 - categorical_accuracy: 1.0000 - val_loss: 1.6339 - val_categorical_accuracy: 0.7619
# Epoch 1457/1500
# 1/1 [==============================] - 1s 575ms/step - loss: 0.0545 - categorical_accuracy: 1.0000 - val_loss: 1.6464 - val_categorical_accuracy: 0.7619
# Epoch 1458/1500
# 1/1 [==============================] - 0s 357ms/step - loss: 0.0773 - categorical_accuracy: 1.0000 - val_loss: 1.6642 - val_categorical_accuracy: 0.7619
# Epoch 1459/1500
# 1/1 [==============================] - 1s 568ms/step - loss: 0.0569 - categorical_accuracy: 1.0000 - val_loss: 1.6715 - val_categorical_accuracy: 0.7619
# Epoch 1460/1500
# 1/1 [==============================] - 0s 367ms/step - loss: 0.0422 - categorical_accuracy: 1.0000 - val_loss: 1.6763 - val_categorical_accuracy: 0.7619
# Epoch 1461/1500
# 1/1 [==============================] - 1s 584ms/step - loss: 0.0432 - categorical_accuracy: 1.0000 - val_loss: 1.6803 - val_categorical_accuracy: 0.7619
# Epoch 1462/1500
# 1/1 [==============================] - 0s 383ms/step - loss: 0.0473 - categorical_accuracy: 1.0000 - val_loss: 1.6837 - val_categorical_accuracy: 0.7619
# Epoch 1463/1500
# 1/1 [==============================] - 1s 618ms/step - loss: 0.0591 - categorical_accuracy: 0.9844 - val_loss: 1.6640 - val_categorical_accuracy: 0.7619
# Epoch 1464/1500
# 1/1 [==============================] - 0s 381ms/step - loss: 0.0425 - categorical_accuracy: 1.0000 - val_loss: 1.6558 - val_categorical_accuracy: 0.7619
# Epoch 1465/1500
# 1/1 [==============================] - 1s 580ms/step - loss: 0.0866 - categorical_accuracy: 0.9844 - val_loss: 1.5804 - val_categorical_accuracy: 0.7619
# Epoch 1466/1500
# 1/1 [==============================] - 0s 384ms/step - loss: 0.0429 - categorical_accuracy: 1.0000 - val_loss: 1.5327 - val_categorical_accuracy: 0.7619
# Epoch 1467/1500
# 1/1 [==============================] - 1s 560ms/step - loss: 0.0450 - categorical_accuracy: 1.0000 - val_loss: 1.4851 - val_categorical_accuracy: 0.7619
# Epoch 1468/1500
# 1/1 [==============================] - 0s 369ms/step - loss: 0.0507 - categorical_accuracy: 1.0000 - val_loss: 1.4572 - val_categorical_accuracy: 0.7619
# Epoch 1469/1500
# 1/1 [==============================] - 1s 581ms/step - loss: 0.0574 - categorical_accuracy: 0.9844 - val_loss: 1.3953 - val_categorical_accuracy: 0.7619
# Epoch 1470/1500
# 1/1 [==============================] - 0s 384ms/step - loss: 0.0426 - categorical_accuracy: 1.0000 - val_loss: 1.3599 - val_categorical_accuracy: 0.8095
# Epoch 1471/1500
# 1/1 [==============================] - 1s 583ms/step - loss: 0.0599 - categorical_accuracy: 1.0000 - val_loss: 1.3358 - val_categorical_accuracy: 0.8571
# Epoch 1472/1500
# 1/1 [==============================] - 0s 351ms/step - loss: 0.0423 - categorical_accuracy: 1.0000 - val_loss: 1.3256 - val_categorical_accuracy: 0.8571
# Epoch 1473/1500
# 1/1 [==============================] - 1s 603ms/step - loss: 0.0865 - categorical_accuracy: 0.9844 - val_loss: 1.2975 - val_categorical_accuracy: 0.8571
# Epoch 1474/1500
# 1/1 [==============================] - 0s 360ms/step - loss: 0.0421 - categorical_accuracy: 1.0000 - val_loss: 1.2850 - val_categorical_accuracy: 0.8571
# Epoch 1475/1500
# 1/1 [==============================] - 1s 592ms/step - loss: 0.0424 - categorical_accuracy: 1.0000 - val_loss: 1.2760 - val_categorical_accuracy: 0.8571
# Epoch 1476/1500
# 1/1 [==============================] - 0s 385ms/step - loss: 0.0468 - categorical_accuracy: 1.0000 - val_loss: 1.2747 - val_categorical_accuracy: 0.8571
# Epoch 1477/1500
# 1/1 [==============================] - 1s 572ms/step - loss: 0.0426 - categorical_accuracy: 1.0000 - val_loss: 1.2739 - val_categorical_accuracy: 0.8095
# Epoch 1478/1500
# 1/1 [==============================] - 0s 421ms/step - loss: 0.0496 - categorical_accuracy: 1.0000 - val_loss: 1.2830 - val_categorical_accuracy: 0.8095
# Epoch 1479/1500
# 1/1 [==============================] - 1s 596ms/step - loss: 0.0425 - categorical_accuracy: 1.0000 - val_loss: 1.2947 - val_categorical_accuracy: 0.7619
# Epoch 1480/1500
# 1/1 [==============================] - 0s 386ms/step - loss: 0.0494 - categorical_accuracy: 1.0000 - val_loss: 1.3141 - val_categorical_accuracy: 0.7619
# Epoch 1481/1500
# 1/1 [==============================] - 1s 598ms/step - loss: 0.0436 - categorical_accuracy: 1.0000 - val_loss: 1.3328 - val_categorical_accuracy: 0.7619
# Epoch 1482/1500
# 1/1 [==============================] - 0s 367ms/step - loss: 0.0879 - categorical_accuracy: 0.9500 - val_loss: 1.3267 - val_categorical_accuracy: 0.8095
# Epoch 1483/1500
# 1/1 [==============================] - 1s 599ms/step - loss: 0.0489 - categorical_accuracy: 1.0000 - val_loss: 1.3607 - val_categorical_accuracy: 0.8095
# Epoch 1484/1500
# 1/1 [==============================] - 0s 368ms/step - loss: 0.0440 - categorical_accuracy: 1.0000 - val_loss: 1.3935 - val_categorical_accuracy: 0.8095
# Epoch 1485/1500
# 1/1 [==============================] - 1s 571ms/step - loss: 0.0442 - categorical_accuracy: 1.0000 - val_loss: 1.4328 - val_categorical_accuracy: 0.8095
# Epoch 1486/1500
# 1/1 [==============================] - 0s 367ms/step - loss: 0.0441 - categorical_accuracy: 1.0000 - val_loss: 1.4658 - val_categorical_accuracy: 0.8095
# Epoch 1487/1500
# 1/1 [==============================] - 1s 567ms/step - loss: 0.1679 - categorical_accuracy: 0.9688 - val_loss: 1.4953 - val_categorical_accuracy: 0.8095
# Epoch 1488/1500
# 1/1 [==============================] - 0s 369ms/step - loss: 0.1993 - categorical_accuracy: 0.9500 - val_loss: 1.4719 - val_categorical_accuracy: 0.8095
# Epoch 1489/1500
# 1/1 [==============================] - 1s 568ms/step - loss: 0.0562 - categorical_accuracy: 1.0000 - val_loss: 1.4626 - val_categorical_accuracy: 0.8095
# Epoch 1490/1500
# 1/1 [==============================] - 0s 369ms/step - loss: 0.0421 - categorical_accuracy: 1.0000 - val_loss: 1.4725 - val_categorical_accuracy: 0.8095
# Epoch 1491/1500
# 1/1 [==============================] - 1s 577ms/step - loss: 0.0426 - categorical_accuracy: 1.0000 - val_loss: 1.4863 - val_categorical_accuracy: 0.7619
# Epoch 1492/1500
# 1/1 [==============================] - 0s 356ms/step - loss: 0.0424 - categorical_accuracy: 1.0000 - val_loss: 1.5037 - val_categorical_accuracy: 0.7619
# Epoch 1493/1500
# 1/1 [==============================] - 1s 577ms/step - loss: 0.0438 - categorical_accuracy: 1.0000 - val_loss: 1.5301 - val_categorical_accuracy: 0.8095
# Epoch 1494/1500
# 1/1 [==============================] - 0s 366ms/step - loss: 0.0423 - categorical_accuracy: 1.0000 - val_loss: 1.5582 - val_categorical_accuracy: 0.8095
# Epoch 1495/1500
# 1/1 [==============================] - 1s 598ms/step - loss: 0.0560 - categorical_accuracy: 0.9844 - val_loss: 1.5754 - val_categorical_accuracy: 0.8095
# Epoch 1496/1500
# 1/1 [==============================] - 0s 368ms/step - loss: 0.0421 - categorical_accuracy: 1.0000 - val_loss: 1.5971 - val_categorical_accuracy: 0.8095
# Epoch 1497/1500
# 1/1 [==============================] - 1s 599ms/step - loss: 0.0429 - categorical_accuracy: 1.0000 - val_loss: 1.6195 - val_categorical_accuracy: 0.8095
# Epoch 1498/1500
# 1/1 [==============================] - 0s 350ms/step - loss: 0.0732 - categorical_accuracy: 1.0000 - val_loss: 1.6412 - val_categorical_accuracy: 0.8095
# Epoch 1499/1500
# 1/1 [==============================] - 1s 569ms/step - loss: 0.0811 - categorical_accuracy: 0.9688 - val_loss: 1.6081 - val_categorical_accuracy: 0.8095
# Epoch 1500/1500
# 1/1 [==============================] - 0s 388ms/step - loss: 0.0435 - categorical_accuracy: 1.0000 - val_loss: 1.6158 - val_categorical_accuracy: 0.8095

# %% [markdown]
# Evaluation of Accuracy

# %%
scores = model.evaluate(X_test, Y_test) # let's look at the accuracy on the test set
print("Accuracy test: %.2f%%" % (scores[1]*100))
# Out:
# 21/21 [==============================] - 0s 3ms/step
# Accuracy test: 80.95%

# %%
from sklearn.metrics import precision_recall_fscore_support as prfs

Y_pred = model.predict_classes(X_test)

# %%
precision, recall, f1, support = prfs(y_test, Y_pred, average='weighted')
print("Precision: {:.2%}\nRecall: {:.2%}\nF1 score: {:.2%}\nAccuracy: {:.2%}".format(precision, recall, f1, scores[1]))
# Out:
# Precision: 80.68%
# Recall: 80.95%
# F1 score: 80.49%
# Accuracy: 80.95%

# %% [markdown]
# # Check upon a test set

# %%
from sklearn.metrics import precision_recall_fscore_support as prfs

# Preparing for metrics check-up on the test set,
Y_pred = model.predict_classes(X_test)

# %%
precision, recall, f1, support = prfs(y_test, Y_pred, average='weighted')
print("Precision: {:.2%}\nRecall: {:.2%}\nF1 score: {:.2%}\nAccuracy: {:.2%}".format(precision, recall, f1, scores[1]))
# Out:
# Precision: 80.68%
# Recall: 80.95%
# F1 score: 80.49%
# Accuracy: 80.95%

# %%
# But let's check per class,
precision_, recall_, f1_, support_ = prfs(y_test, Y_pred, average=None)

# %%
# Graph according to dataset..
plt.subplots(figsize=(18,30))
x = range(len(cars))
plt.subplot(311)
plt.title('Precision per class')
plt.ylim(0.85, 1.00)
plt.bar(x, precision_, color='Red')
plt.xticks(x, cars, rotation = 90)
plt.subplot(312)
plt.title('Recall per class')
plt.ylim(0.85, 1.00)
plt.bar(x, recall_, color='Green')
plt.xticks(x, cars, rotation = 90)
plt.subplot(313)
plt.title('F1 score per class')
plt.ylim(0.85, 1.00)
plt.bar(x, f1_, color='Blue')
plt.xticks(x, cars, rotation = 90)
plt.show()

# %%
def ImageConvert(n, i):
    im_ex = i.reshape(n, img_x, img_y, 3)
    im_ex = im_ex.astype('float32') / 255
    # zero center data
    im_ex = np.subtract(im_ex, 0.5)
    # ...and to scale it to (-1, 1)
    im_ex = np.multiply(im_ex, 2.0)
    return im_ex

X_train = ImageConvert(X_train.shape[0], X_train)
X_test = ImageConvert(X_test.shape[0], X_test)

def ShowCase(cols, rows):
    fdict = {'fontsize': 24,
            'fontweight' : 'normal',
            'verticalalignment': 'baseline'}
    plt.figure(figsize=(cols * 5, rows * 4))
    plt.subplots_adjust(bottom=0, left=.01, right=.99, top=.90, hspace=.35)
    c = 0
    for i in range(rows * cols):
        plt.subplot(rows, cols, i + 1)
        
        # r - randomly picked from the whole dataset
        r = np.random.randint(np.shape(images)[0])
        
        # j - predicted class for the image of index r (weird syntax, but works :)
        j = int(model.predict_classes(ImageConvert(1, images[r:r+1]), verbose=0))
        
        # increase success if predicted well
        if labels[r] == j:
            c += 1
        
        # image needs reshaping back to a 50px*50px*RGB
        plt.imshow(images[r].reshape(img_x, img_y, 3))
        
        # plt.title will show the true brand and the predicted brand
        plt.title('True brand: '+cars[labels[r]]+'\nPredicted: '+cars[j],
                  color= 'Green' if cars[labels[r]] == cars[j] else 'Red', fontdict=fdict) # Green for right, Red for wrong
        
        # no ticks
        plt.xticks(())
        plt.yticks(())
        
    # print out the success rate
    print('Success rate: {}/{} ({:.2%})'.format(c, rows*cols, c/(rows*cols)))
    
    plt.show()

# %%
# That is strictly for the showcasing, how the CNN works -
ShowCase(10, 5)
# Out:
# Success rate: 47/50 (94.00%)

# %%
# Setting up the image pool
new_image_path = 'new_img/'
new_imgs = os.listdir(new_image_path)
new_n_samples = np.size(new_imgs)
new_n_samples # 8
# Out:
# 8

# %%
# Let's do some showcasing on-the-fly....
# %matplotlib inline
cols = 8
rows = 1
plt.figure(figsize=(cols * 5, rows * 4))
plt.subplots_adjust(bottom=0, left=.01, right=.99, top=.90, hspace=.35)
for i in range(new_n_samples):
    plt.subplot(rows, cols, i + 1)
    im = Image.open(new_image_path+new_imgs[i]).convert("RGB")
    new_im = np.array(im.resize((50,50))).flatten()
    m = int(model.predict_classes(ImageConvert(1, new_im), verbose=0))
    plt.imshow(new_im.reshape(img_x, img_y, 3))
    plt.title('Predicted brand: '+cars[m], size=24)
    plt.xticks(())
    plt.yticks(())
plt.show()
